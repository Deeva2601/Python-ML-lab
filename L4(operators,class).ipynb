# %% [markdown]
# <a href="https://colab.research.google.com/github/Deeva2601/Python-ML-lab/blob/main/L4(operators%2Cclass).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #left and right shift

# %%
n=9
print(n,'binary',format(n,'b'))
print(n,'* 2 =',n<<1,format(n<<1,'b'))
print(n,'/ 2 =',n>>1,format(n>>1,'b'))
# Out:
# 9 binary 1001
# 9 * 2 = 18 10010
# 9 / 2 = 4 100

# %% [markdown]
# Operators

# %%
x = True
y = False
print('x and y is',x and y)
print('x or y is', x or y)
print('not x is ',not x)
# Out:
# x and y is False
# x or y is True
# not x is  False

# %%
x = True
y = False
print('x or y is', x or y)
print('x | y is', x | y)
# Out:
# x or y is True
# x | y is True

# %%
x = 12
y = 4
print(x & y)
print(x | y)
print(x ^ y)
# Out:
# 4
# 12
# 8

# %% [markdown]
# In and Not In

# %%
x = 'Hello world'
print('H' in x)
print('h' not in x)
# Out:
# True
# True

# %% [markdown]
# we use complex class a is the object of complex class

# %%
import cmath
a = complex(20+5j)
b = complex(5+3j)
print('a+b',a+b)
print('a-b',a-b)
print('a*b',a*b)
print('a/b',a/b)
# Out:
# a+b (25+8j)
# a-b (15+2j)
# a*b (85+85j)
# a/b (3.3823529411764706-1.0294117647058825j)

# %% [markdown]
# without cmath library

# %%
a = complex(20+5j)
b = complex(5+3j)
print('a+b',a+b)
print('a-b',a-b)
print('a*b',a*b)
print('a/b',a/b)
# Out:
# a+b (25+8j)
# a-b (15+2j)
# a*b (85+85j)
# a/b (3.3823529411764706-1.0294117647058825j)

# %%
a = int

# %%
import math

a = float(input("Enter the value of a:"))
b = float(input("Enter the value of b:"))
c = float(input("Enter the value of c:"))

s = (a + b + c) / 2
print('s', s)

area = s * (s - a) * (s - b) * (s - c)

print(area)
# Out:
# Enter the value of a:3
# Enter the value of b:3
# Enter the value of c:3
# s 4.5
# 15.1875

# %% [markdown]
# if-elif

# %% [markdown]
# write a program that accept a lowercase/uppercase char and check whether the character is a vowel or constant

# %%
ch = input("Enter a letter:")
ch = ch.lower()
if(ch == 'a'or ch =='e'or ch =='i'or ch =='o'or ch == 'u'):
  print("Character enter in vowel")
else:
  print("Character is constant")
# Out:
# Enter a lettere
# Character enter in vowel

# %% [markdown]
# write a program to check whether a given character is a digit or a character in uppercase or lowercase.

# %%
char = input("Enter a value: ")

if len(char) == 1:
    if char.isdigit():
        print("It's a digit.")
    elif char.isupper():
        print("It's an uppercase character.")
    elif char.islower():
        print("It's a lowercase character.")
    else:
        print("It's a special character.")
# Out:
# Enter a value: a
# It's a lowercase character.

# %% [markdown]
# write a program in python to print table of any numbr n using while loop

# %%
n = int(input("Enter any number"))
table = [n * i for i in range(1,11)]
print(table)
# Out:
# Enter any number5
# [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]

# %% [markdown]
# write a program in python to evaluate factorial

# %%
num = 5
fact = 1

for i in range(1, num + 1):
    fact *= i

print("Factorial =", fact)
# Out:
# Factorial = 120

# %% [markdown]
# write a program in python to enter a number  till the user wants display the maximum number using while loop

# %%
max_num = 0
while True:
    num = int(input("Enter a number: "))
    if num > max_num:
        max_num = num
    choice = input("Enter more? (y/n): ")
    if choice == 'n':
        break

print("Maximum number is:", max_num)

# %% [markdown]
# Class

# %%
class Car:
  # self is a reference to the instance of the class
  def  __init__(self, brand, model, year):
    self.brand = brand # Attribute
    self.model = model
    self.year = year

  def display_Info(self):
    # Use f-strings for easier formatting
    print(f"Car: {self.brand} {self.model} {self.year}")

# Create instances of the Car class OUTSIDE the class definition
car1 = Car("Toyota", "corolla", 2022)
car3 = Car("Tesla", "Model S", 2022)

# Call methods on the instances
car1.display_Info()
car3.display_Info() # Corrected from car2 to car3
# Out:
# Car: Toyota corolla 2022
# Car: Tesla Model S 2022

# %%
class Employee:
  def __init__(self,Name,company,salary):
    self.Name = Name
    self.company = company
    self.salary = salary
  def display_Info(self):
    print(f"Employee: {self.Name} {self.company} {self.salary}")

Employee1 = Employee("John", "Google", 50000)
Employee2 = Employee("Alice", "Microsoft", 60000)


Employee1.display_Info()
Employee2.display_Info()
# Out:
# Employee: John Google 50000
# Employee: Alice Microsoft 60000

# %%
class Student:
    def __init__(self, Name, Age, Marks):
        self.Name = Name
        self.Age = Age
        self.Marks = Marks

    def display(self):
        print("Name:", self.Name)
        print("Age:", self.Age)
        print("Marks:", self.Marks)

students = [
    Student("Alice", 20, 50),
    Student("Bob", 22, 60),
    Student("Charlie", 21, 70),
]

for student in students:
    student.display()
# Out:
# Name: Alice
# Age: 20
# Marks: 50
# Name: Bob
# Age: 22
# Marks: 60
# Name: Charlie
# Age: 21
# Marks: 70

# %%
class Employee:
  def __init__(self,emp_id,name,salary):
    self.emp_id = emp_id
    self.name = name
    self.salary = salary
  def display(self):
    print(f"ID:{self.emp_id}, Name: {self.name}, Salary: {self.salary}")

employees = {
    101 : Employee(101,"John",60000),
    102 : Employee(102,"sohn",6000),
    103 : Employee(103,"Rohan",23000),
}

for emp_id,emp in employees.items():
  emp.display()
# Out:
# ID:101, Name: John, Salary: 60000
# ID:102, Name: sohn, Salary: 6000
# ID:103, Name: Rohan, Salary: 23000
