# %% [markdown]
# <a href="https://colab.research.google.com/github/Deeva2601/Python-ML-lab/blob/main/Copy_of_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Name- Deeva Jain, Enrollment- 0827CI231032, Subject- Python

# %%
def funct1():
  print("hello")
funct1()
# Out:
# hello

# %%
def funct1(fname):
  print(fname)
funct1("fchchg")
# Out:
# fchchg

# %%
def funct1(fname, lname ):
  print(fname + "  " +lname)
funct1("fchchg", "vsdvhsg")
# Out:
# fchchg  vsdvhsg

# %%
def funct1(*kid):
  print(kid[2])
funct1("a", "b", "c")
funct1("a", "b", "r", "d")
funct1("a", "b", "t", "d", "e")
# Out:
# c
# r
# t

# %%
def funct1( k,j,i):
  print(" the values of i = {}, j={}, k={}" .format(i,j,k))

funct1(i=2, j=6, k=8)
# Out:
#  the values of i = 2, j=6, k=8

# %%
def funct1( ** var):
   print(var["i"])
funct1(i=2, j=6, k=8)
# Out:
# 2

# %%
def funct1(food):
  for i in food:
    print(i)

fruits=["apple", "banana", "cherry"]
funct1(fruits)
# Out:
# apple
# banana
# cherry

# %%
def funct1 (country='India'):
  print ("my country name is " + country)
funct1("newyork")
funct1()
# Out:
# my country name is newyork
# my country name is India

# %%
def funct1 (x):
  return 5*x

print(funct1(5))
# Out:
# 25

# %%
def funct1 ():
  pass

# %%
x=10
def funct1():
  x=10
  x= x*10
  print(x)

funct1()
print(x)
# Out:
# 100
# 10

# %%
x=10
def funct1():
  x=globals()['x']
  x=10
  x= x*10
  globals()['x']=x
  print(x)

funct1()
print(x)
# Out:
# 100
# 100

# %%
x=10
def funct1():
  global x
  x= x*100
  print(x)

funct1()
print(x)
# Out:
# 1000
# 1000

# %%
# explicitly float accept  what to do
def greet(name:float):
  print(type(name))
greet(1234)
greet("welcome")
# Out:
# <class 'int'>
# <class 'str'>

# %%
num= input("enter a number")
num
# Out:
# enter a number4
# '4'

# %%
str= input("enter a string"). split(",")
# Out:
# enter a stringDeeva

# %%
str
# Out:
# ['Deeva']

# %%
print(1,2,3,4)
# Out:
# 1 2 3 4

# %%
print(1,2,3,4, sep='*')
# Out:
# 1*2*3*4

# %%
print(1,2,3,4, sep='*' ,end= '&')
print(1,2,3,4, sep='*')
# Out:
# 1*2*3*4&1*2*3*4

# %%
x=3;y=4
print( "vcnsv{1}jhsjhd{0}" . format(x,y))
# Out:
# vcnsv4jhsjhd3

# %%
print( "{}jghcjgcj{}" . format('bread', 'butter'))
print( "{1}jghcjgcj{0}" . format('bread', 'butter'))
# Out:
# breadjghcjgcjbutter
# butterjghcjgcjbread

# %% [markdown]
# List Function

# %%
#1 append() -> end me value add krta h
a = [1,2,3]
a.append(4)
print(a)
# Out:
# [1, 2, 3, 4]

# %%
#2 insert() -> specific position par value add
a = [1,2,3]
a.insert(1,100)
print(a)
# Out:
# [1, 100, 2, 3]

# %%
#3 remove() -> value remove krta h
a = [10,20,30]
a.remove(20)
print(a)
# Out:
# [10, 30]

# %%
#4 pop() ->index se delete
a = [1,2,3]
a.pop(1)
print(a)
# Out:
# [1, 3]

# %%
#5 sort() -> ascending order
a = [5,2,8,1]
a.sort()
print(a)
# Out:
# [1, 2, 5, 8]

# %% [markdown]
# # **Dictionary Functions**

# %%
#6 keys() -> all keys print
d = {"name":"Deeva","age":21}
print(d.keys())
# Out:
# dict_keys(['name', 'age'])

# %%
#7 values() -> all values print
d = {"name":"Deeva","age":21}
print(d.values())
# Out:
# dict_values(['Deeva', 21])

# %%
#8 items() -> key value pair
d = {"name":"Deeva"}
print(d.items())
# Out:
# dict_items([('name', 'Deeva')])

# %%
#9 get() -> safely value access
d = {"name":"Deeva"}
print(d.get("name"))
# Out:
# Deeva

# %%
#10 update() -> dictionary update
d = {"a":1}
d.update({"b":2})
print(d)
# Out:
# {'a': 1, 'b': 2}

# %% [markdown]
# # **String Function**

# %%
#11 upper() -> capital letter
s = "deeva"
print(s.upper())
# Out:
# DEEVA

# %%
#12 lower() ->small letters
s = "HELLO"
print(s.lower())
# Out:
# hello

# %%
#13 replace() -> word replace
s ="I like java"
print(s.replace("java","python"))
# Out:
# I like python

# %%
#14 split() -> string split
s = "apple banana mango"
print(s.split())
# Out:
# ['apple', 'banana', 'mango']

# %%
#15. find() -> index find
s = "python"
print(s.find("t"))
# Out:
# 2

# %% [markdown]
# # **Set function**

# %%
#16 add() -> value add
s = {1,2,3}
s.add(4)
print(s)
# Out:
# {1, 2, 3, 4}

# %%
#17 remove() -> remove value
s = {1,2,3}
s.remove(2)
print(s)
# Out:
# {1, 3}

# %%
#18 union() -> combine sets
s ={1,2}
q = {3,4}
print(s.union(q))
# Out:
# {1, 2, 3, 4}

# %%
#19 intersection() -> common value
a = {1,2,3}
b ={2,3,4}
print(a.intersection(b))
# Out:
# {2, 3}

# %%
#20 clear() -> empty set
s ={1,2}
s.clear()
print(s)
# Out:
# set()

# %% [markdown]
# # **Tuple Functions**

# %%
#21 count() -> count repeated value
t = (1,2,2,3)
print(t.count(2))
# Out:
# 2

# %%
#22 index() -> position findO
t =(10,20,30)
print(t.index(20))
# Out:
# 1

# %%
#23 len() -> tuple length
t = (1,2,3)
print(len(t))
# Out:
# 3

# %%
#24 max() -> minimum value
t = (4,8,2)
print(min(t))
# Out:
# 2

# %%
#25 min() -> minimum value
t =(4,6,1)
print(min(t) )
# Out:
# 1
